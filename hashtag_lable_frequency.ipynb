# %%
import pandas as pd
import numpy as np

# %%
lable1= pd.read_csv('lable_crawling.csv')
lable1
# Out:
#    Unnamed: 0 여행스타그램1.jpg     여행스타그램2.jpg 여행스타그램3.jpg       여행스타그램4.jpg  \
# 0           0    Clothing          Flower        Hair               Dog
# 1           1      Beauty         Blossom        Face        Vertebrate
# 2           2   Outerwear          Spring   Hairstyle           Canidae
# 3           3      Blazer  Cherry blossom       Bangs            Mammal
# 4           4         Leg           Plant  Black hair        Toy Poodle
# 5           5     Sitting            Tree      Beauty         Dog breed
# 6           6    Leggings          Branch        Head          Maltepoo
# 7           7      Tights            Twig   Long hair  Miniature Poodle
# 8           8      Jacket     Woody plant         Lip     Companion dog
# 9           9      Sleeve          Prunus     Eyebrow              Head
#
#   여행스타그램5.jpg
# 0        Hair
# 1        Face
# 2         Lip
# 3  Black hair
# 4     Eyebrow
# 5   Hairstyle
# 6        Skin
# 7      Beauty
# 8   Long hair
# 9      Selfie

# %%
lable1.shape
# Out:
# (10, 6)

# %%
hashtag1 = pd.read_csv('hashtag_crawling.csv').iloc[:,:10]
hashtag1
# Out:
#      Unnamed: 0              0             1         2         3        4  \
# 0             0    여행스타그램1.jpg           NaN       NaN       NaN      NaN
# 1             1    여행스타그램2.jpg     portra160  canonae1     제주도벚꽃  맑음_봄을담다
# 2             2    여행스타그램3.jpg           NaN       NaN       NaN      NaN
# 3             3    여행스타그램4.jpg           NaN       NaN       NaN      NaN
# 4             4    여행스타그램5.jpg  likeforlikes    선팔하면맞팔        훈남   뷰티스타그램
# ..          ...            ...           ...       ...       ...      ...
# 474         474  여행스타그램475.jpg            패션     가족나들이       피부과     다이어터
# 475         475  여행스타그램476.jpg       광안리해수욕장    広安里ビーチ       피크닉      女子旅
# 476         476  여행스타그램477.jpg            촬영      인물사진        여행      유채꽃
# 477         477  여행스타그램478.jpg            좋반        타투  likelike   패션스타그램
# 478         478            여행스           NaN       NaN       NaN      NaN
#
#           5                6       7       8
# 0       NaN              NaN     NaN     NaN
# 1        벚꽃              무보정  jejudo   캐논ae1
# 2       NaN              NaN     NaN     NaN
# 3       NaN              NaN     NaN     NaN
# 4      선팔환영             좋반테러     구시청      광주
# ..      ...              ...     ...     ...
# 474    인천공항              미용실      한강   보조베터리
# 475  picnic           海ピクニック    釜山旅行      釜山
# 476       🌼               서울  여행스타그램  2470gm
# 477    선팔맞팔  followforfollow    첫줄반사  뷰티스타그램
# 478     NaN              NaN     NaN     NaN
#
# [479 rows x 10 columns]

# %%
hashtag1.shape
# Out:
# (479, 10)

# %% [markdown]
# #### 각 lable별로 hashtag가 해당되면 빈도수 누적합산하기

# %%
freq1 = pd.to_csv('./freq1.csv')
freq1
