# %%
import pandas as pd
import numpy as np

# %%
temp1 = pd.read_csv('temp.csv').iloc[:,:15]
temp1.shape
# Out:
# (899, 15)

# %%
temp1.head(50)
# Out:
#                        Unnamed: 0  Unnamed: 1  천년만에  벚꽃명소  탈출  코로나형  쌩얼  가끔  \
# 0                           Smile           0     0     0   0     0   0   0
# 1                             NaN           0     0     0   0     0   0   0
# 2                            Face           0    39    39  39    39  39  39
# 3               Medical equipment           0     0     0   0     0   0   0
# 4                            Neck           0     0     0   0     0   0   0
# 5                            Head           0     0     0   0     0   0   0
# 6                            Chin           0     0     0   0     0   0   0
# 7                           Mouth           0     0     0   0     0   0   0
# 8                             Jaw           0     0     0   0     0   0   0
# 9               Fashion accessory           0     0     0   0     0   0   0
# 10                         Collar           0     0     0   0     0   0   0
# ...

# %%
lable1= pd.read_csv('lable_crawling.csv')
lable1
# Out:
#    Unnamed: 0 여행스타그램1.jpg     여행스타그램2.jpg 여행스타그램3.jpg       여행스타그램4.jpg  \
# 0           0    Clothing          Flower        Hair               Dog
# 1           1      Beauty         Blossom        Face        Vertebrate
# 2           2   Outerwear          Spring   Hairstyle           Canidae
# 3           3      Blazer  Cherry blossom       Bangs            Mammal
# 4           4         Leg           Plant  Black hair        Toy Poodle
# 5           5     Sitting            Tree      Beauty         Dog breed
# 6           6    Leggings          Branch        Head          Maltepoo
# 7           7      Tights            Twig   Long hair  Miniature Poodle
# 8           8      Jacket     Woody plant         Lip     Companion dog
# 9           9      Sleeve          Prunus     Eyebrow              Head
#
#   여행스타그램5.jpg
# 0        Hair
# 1        Face
# 2         Lip
# 3  Black hair
# 4     Eyebrow
# 5   Hairstyle
# 6        Skin
# 7      Beauty
# 8   Long hair
# 9      Selfie

# %%
lable1.shape
# Out:
# (10, 6)

# %%
hashtag1 = pd.read_csv('hashtag_crawling.csv').iloc[:,:10]
hashtag1.head(5)
# Out:
#    Unnamed: 0            0             1         2      3        4     5  \
# 0           0  여행스타그램1.jpg           NaN       NaN    NaN      NaN   NaN
# 1           1  여행스타그램2.jpg     portra160  canonae1  제주도벚꽃  맑음_봄을담다    벚꽃
# 2           2  여행스타그램3.jpg           NaN       NaN    NaN      NaN   NaN
# 3           3  여행스타그램4.jpg           NaN       NaN    NaN      NaN   NaN
# 4           4  여행스타그램5.jpg  likeforlikes    선팔하면맞팔     훈남   뷰티스타그램  선팔환영
#
#       6       7      8
# 0   NaN     NaN    NaN
# 1   무보정  jejudo  캐논ae1
# 2   NaN     NaN    NaN
# 3   NaN     NaN    NaN
# 4  좋반테러     구시청     광주

# %%
hashtag1.shape
# Out:
# (479, 10)

# %% [markdown]
# #### 각 lable별로 hashtag가 해당되면 빈도수 누적합산하기

# %%
freq1 = pd.to_csv('./freq1.csv')
freq1
